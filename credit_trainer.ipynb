# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import pandas as pd

# %%
# Load first 1000 lines of data
applicant_gp_1 = pd.read_csv('Resources/MOCK_DATA_first.csv')
applicant_gp_1.head()
# Out:
#   first_name   last_name state                      job_title     salary  \
# 0     Kerrin  Thompstone    WI               Junior Executive  $31330.62
# 1     Valida       Goffe    MO            Associate Professor  $34173.05
# 2    Rollins      Fellon    NY                   Accountant I  $55615.74
# 3  Grenville      McArte    WV  Analog Circuit Design manager  $36675.24
# 4      Micah      Yurkin    TX                      Professor  $36377.32
#
#    tenure  credit_score  age sex loan_amount  interest_rate  checking_savings  \
# 0      19           726   85   F  $116286.60            3.8           9297.29
# 1      23           581   41   F  $365584.56            3.6           3333.93
# 2      22           795   72   M  $221657.40            2.7             39.46
# 3      20           770   78   M     $216.20            2.6           8518.11
# 4      19           360   56   M   $67730.67            3.4           5067.22
#
#   existing_debt
# 0      $8083.40
# 1     $12537.18
# ...

# %%
# Load second 1000 lines of data
applicant_gp_2 = pd.read_csv('Resources/MOCK_DATA_Second.csv')
applicant_gp_2.head()
# Out:
#    first_name last_name state                      job_title     salary  \
# 0   Zachariah   Filasov    FL  Budget/Accounting Analyst III  $37138.31
# 1       Prudy      Aggs    IN              Marketing Manager  $31510.71
# 2       Holly    Megson    LA        Senior Quality Engineer  $52158.78
# 3       Marsh    Jandak    PA             VP Quality Control  $56137.11
# 4  Westbrooke    Delort    FL               Product Engineer  $46404.58
#
#    tenure  credit_score  age sex loan_amount  interest_rate  checking_savings  \
# 0      14           787   70   M  $471049.84            3.8            298.35
# 1      14           748   24   F  $267035.18            2.5           7761.01
# 2       9           717   74   M  $158668.63            2.5           -886.96
# 3      11           579   56   M  $270814.76            2.7           1905.22
# 4       7           499   74   M   $55420.65            3.8           1636.19
#
#   existing_debt
# 0     $34126.96
# 1     $15146.32
# ...

# %%
all_applicants = pd.merge(applicant_gp_1, applicant_gp_2, how='outer')
all_applicants.tail()
# Out:
#      first_name    last_name state                 job_title     salary  \
# 1995     Justis     Verecker    CA   Assistant Media Planner  $47328.04
# 1996   Carlynne      Smowton    OH                 Professor  $51287.99
# 1997   Tremaine          Saw    DC            Statistician I  $33529.18
# 1998      Hedda  Ravenscroft    NM  Database Administrator I  $54137.69
# 1999     Dorisa      O'Kerin    NC          Technical Writer  $33961.24
#
#       tenure  credit_score  age sex loan_amount  interest_rate  \
# 1995       2           655   28   M  $375044.52            3.1
# 1996      11           531   54   F  $474186.63            3.4
# 1997      23           387   57   M   $76526.71            4.0
# 1998      13           692   85   F   $85125.68            4.0
# 1999      25           518   57   F  $207048.62            2.6
#
#       checking_savings existing_debt
# 1995           6437.95     $72285.62
# 1996           5367.39     $59355.81
# 1997           1987.78     $27643.72
# ...

# %%
all_applicants.drop(['job_title'], axis=1)
all_applicants.head()
# Out:
#   first_name   last_name state                      job_title     salary  \
# 0     Kerrin  Thompstone    WI               Junior Executive  $31330.62
# 1     Valida       Goffe    MO            Associate Professor  $34173.05
# 2    Rollins      Fellon    NY                   Accountant I  $55615.74
# 3  Grenville      McArte    WV  Analog Circuit Design manager  $36675.24
# 4      Micah      Yurkin    TX                      Professor  $36377.32
#
#    tenure  credit_score  age sex loan_amount  interest_rate  checking_savings  \
# 0      19           726   85   F  $116286.60            3.8           9297.29
# 1      23           581   41   F  $365584.56            3.6           3333.93
# 2      22           795   72   M  $221657.40            2.7             39.46
# 3      20           770   78   M     $216.20            2.6           8518.11
# 4      19           360   56   M   $67730.67            3.4           5067.22
#
#   existing_debt
# 0      $8083.40
# 1     $12537.18
# ...

# %%
print(all_applicants.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
data_df = all_applicants.drop(['job_title', 'sex'],  axis=1)
data_df.head()
# Out:
#   first_name   last_name state     salary  tenure  credit_score  age  \
# 0     Kerrin  Thompstone    WI  $31330.62      19           726   85
# 1     Valida       Goffe    MO  $34173.05      23           581   41
# 2    Rollins      Fellon    NY  $55615.74      22           795   72
# 3  Grenville      McArte    WV  $36675.24      20           770   78
# 4      Micah      Yurkin    TX  $36377.32      19           360   56
#
#   loan_amount  interest_rate  checking_savings existing_debt
# 0  $116286.60            3.8           9297.29      $8083.40
# 1  $365584.56            3.6           3333.93     $12537.18
# 2  $221657.40            2.7             39.46     $55147.37
# 3     $216.20            2.6           8518.11      $9871.60
# 4   $67730.67            3.4           5067.22     $67733.55

# %%
data_df.to_csv('Resources/dataOnly.csv', index=False, header=True)

# %%
all

# %%
data_df.dtypes
# Out:
# first_name           object
# last_name            object
# state                object
# salary               object
# tenure                int64
# credit_score          int64
# age                   int64
# loan_amount          object
# interest_rate       float64
# checking_savings    float64
# existing_debt        object
# dtype: object

# %%
data_df['existing_debt'] = pd.to_numeric(data_df['existing_debt'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "$8083.40"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-9c977fd03f07> in <module>
# ----> 1 data_df['existing_debt'] = pd.to_numeric(data_df['existing_debt'])
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     151         try:
#     152             values = lib.maybe_convert_numeric(
# --> 153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#     155         except (ValueError, TypeError):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ...

# %%
data_df["DTI"] = (
    data_df["existing_debt"]/data_df["salary"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
#
# ...

# %%
import tensorflow
tensorflow.keras.__version__
# Out:
# '2.2.4-tf'
